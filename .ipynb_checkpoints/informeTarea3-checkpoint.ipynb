# %% [markdown]
# ### Entrega 3 - Clasifcador bayesiano sencillo y KNN
#
# ### Grupo 14:
#      - Santiago Bianchi  C.I 4.523.351-3
#      - Santiago Rodriguez C.I 5.154.441-3
#      - Gonzalo Rosso C.I 4.244.387-4

# %% [markdown]
# ## 1. Objetivo

# %% [markdown]
# El objetivo de esta tarea es trabajar basados en el teorema de Bayes<sup>1</sup>, en particular con un clasificador Bayesiano sencillo<sup>2</sup> y también con el algoritmo K-Nearest Neighbor<sup>3</sup>.
#
# Al igual que en la tarea anterior también se trabaja sobre los conjuntos datos Iris<sup>4</sup> y Forest Covertype <sup>5</sup>.
#
# Por último se desean comparar los resultados obtenidos con los algoritmos descritos en este informe y el algoritmo ID3 de la tarea anterior.

# %% [markdown]
# ## 2. Diseño

# %% [markdown]
# A continuación se presentarán las bases de cada algoritmo sobre la que se trabajó y el fundamento teórico tras cada paso seguido.

# %% [markdown]
# ## 2.1 Clasificador Bayesiano Sencillo
#
# Comenzamos describiendo los pasos del algoritmo con el que trabajamos:
# ```
# 1. Separamos los datos por clase
# 2. Pasamos a calcular predicciones basados en probabilidades
# 3. Calculamos dependiendo si el atributo es categórico o continuo
#     3.1 Para el caso de atributos continuos utilizamos la media y desviación estandar
#     3.2 Para atributos categórigos nos basamos en cantidad de ocurrencias
# 4. Calculamos precisión
# ```
#
# ### 2.1.1 Adaptación
#
# Explicar adaptación del algoritmo para aceptar atr. categ.

# %% [markdown]
# ## 2.2 K-Nearest Neighbor
#
# Comenzamos describiendo con pseudocódigo el algoritmo con el que comenzamos a trabajar.
# ```
# explicar en pseudocodigo
# ```

# %% [markdown]
# ## 2.2 Teorema de Bayes
#
# Expresa la probabilidad condicional de un evento aleatorio A dado B en términos de la distribución de probabilidad condicional del evento B dado A y la distribución de probabilidad marginal de sólo A.
#
# En resumen, la mejor hipótesis es la hipótesis más probable según los datos previos que se tienen.
#
# $$ P(h|D) = P(D|h)P(h) / P(D)$$

# %% [markdown]
# ## 3. Experimentación<sup>7</sup>

# %% [markdown]
# Luego de implementado el clasificador Bayesiano sencillo tal como se describió anteriormente y también de haber implementado el algoritmo KNN, es que procedimos a realizar pruebas con ambos conjuntos de datos (conjunto Iris y conjunto Forest Covertype).
#
# Nos basamos en varios tipos de pruebas para calcular los errores,tanto para evaluar conjuntos completos como en subdividir los conjuntos. En todos los casos tomamos una proporción 80-20 para dividir los conjuntos en una parte para entrenamiento y la otra para pruebas.

# %% [markdown]
# ### 3.1 Pruebas sobre conjunto Iris
#
# #### 3.1.1 Clasificador Bayesiano simple
#
# #### 3.1.2 K-Nearest Neighbor
#
# <table style="text-align:center;float:left">
#     <thead>
#         <tr>
#             <td>Ejecución</td>
#             <td>Entrenamiento</td>
#             <td>Test</td>
#         </tr>
#     </thead>
#     <tr>
#         <td>1</td>
#         <td>0.016</td>
#         <td>0.066</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0.016</td>
#         <td>0.13</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0.025</td>
#         <td>0.066</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0.033</td>
#         <td>0.033</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>0.025</td>
#         <td>0.1</td>
#     </tr>
#      <tr>
#         <td>Promedio</td>
#         <td>0.023</td>
#         <td>0.079</td>
#     </tr>
#
# </table>
# <img src="img/3.1parteA-errores.png" style="float:left;margin-left:50px" width=400/>

# %% [markdown]
# ### 3.2 Pruebas con Forest covertype
#
# #### 3.2.1 Clasificador Bayesiano simple
#
# #### 3.2.2 K-Nearest Neighbor
#
# <table style="text-align:center;float:left">
#     <thead>
#         <tr>
#             <td colspan="3">581/145 elementos</td>
#         </tr>
#         <tr>
#             <td>Ejecución</td>
#             <td>Entrenamiento</td>
#             <td>Prueba</td>
#         </tr>
#     </thead>
#     <tr>
#         <td>1</td>
#         <td>0.29</td>
#         <td>0.5</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0.24</td>
#         <td>0.54</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0.26</td>
#         <td>0.56</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0.16</td>
#         <td>0.45</td>
#     </tr>
#      <tr>
#         <td>Promedio</td>
#         <td>0.24</td>
#         <td>0.51</td>
#     </tr>
#
# </table>
# <table style="text-align:center;float:left;margin-left:20px">
#     <thead>
#         <tr>
#             <td colspan="3">2905/581 elementos</td>
#         </tr>
#         <tr>
#             <td>Ejecución</td>
#             <td>Entrenamiento</td>
#             <td>Prueba</td>
#         </tr>
#     </thead>
#     <tr>
#         <td>1</td>
#         <td>0.35</td>
#         <td>0.52</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0.28</td>
#         <td>0.45</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0.36</td>
#         <td>0.52</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0.35</td>
#         <td>0.47</td>
#     </tr>
#      <tr>
#         <td>Promedio</td>
#         <td>0.33</td>
#         <td>0.49</td>
#     </tr>
#
# </table>
# <table style="text-align:center;float:left;margin-left:20px">
#     <thead>
#         <tr>
#             <td colspan="3">5810/1452 elementos</td>
#         </tr>
#         <tr>
#             <td>Ejecución</td>
#             <td>Entrenamiento</td>
#             <td>Prueba</td>
#         </tr>
#     </thead>
#     <tr>
#         <td>1</td>
#         <td>0.35</td>
#         <td>0.47</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0.39</td>
#         <td>0.48</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0.37</td>
#         <td>0.41</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0.35</td>
#         <td>0.40</td>
#     </tr>
#      <tr>
#         <td>Promedio</td>
#         <td>0.365</td>
#         <td>0.44</td>
#     </tr>
#
# </table>
# <table style="text-align:center;float:left;margin-left:20px">
#     <thead>
#         <tr>
#             <td colspan="3">11620 / 2905 elementos</td>
#         </tr>
#         <tr>
#             <td>Ejecución</td>
#             <td>Entrenamiento</td>
#             <td>Prueba</td>
#         </tr>
#     </thead>
#     <tr>
#         <td>1</td>
#         <td>0.31</td>
#         <td>0.40</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0.28</td>
#         <td>0.33</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0.16</td>
#         <td>0.27</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0.19</td>
#         <td>0.21</td>
#     </tr>
#      <tr>
#         <td>Promedio</td>
#         <td>0.23</td>
#         <td>0.30</td>
#     </tr>
#
# </table>

# %% [markdown]
# ### 3.3 Comparación global
#
# En esta sección comparamos los resultados ya expresados con los obtenidos en la tarea anterior tras implementar el algoritmo ID3.
#
# <table style="text-align:center;float:left">
#     <thead>
#         <tr>
#             <td>Ejecución</td>
#             <td>Entrenamiento Clase 1</td>
#             <td>Entrenamiento Clase 2</td>
#             <td>Entrenamiento Clase 3</td>
#             <td>Entrenamiento Clase 4</td>
#             <td>Entrenamiento Clase 5</td>
#             <td>Entrenamiento Clase 6</td>
#             <td>Entrenamiento Clase 7</td>
#             <td>Test</td>
#         </tr>
#     </thead>
#     <tr>
#         <td>1</td>
#         <td>0.090</td>
#         <td>0.149</td>
#         <td>0.000</td>
#         <td>0.000</td>
#         <td>0.050</td>
#         <td>0.000</td>
#         <td>0.001</td>
#         <td>0.370</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0.059</td>
#         <td>0.143</td>
#         <td>0.025</td>
#         <td>0.008</td>
#         <td>0.045</td>
#         <td>0.046</td>
#         <td>0.005</td>
#         <td>0.391</td>
#     </tr>
#      <tr>
#         <td>Promedio</td>
#         <td>0.074</td>
#         <td>0.146</td>
#         <td>0.012</td>
#         <td>0.004</td>
#         <td>0.047</td>
#         <td>0.023</td>
#         <td>0.003</td>
#         <td>0.380</td>
#     </tr>
#
# </table>

# %% [markdown]
# ## 4. Conclusiones

# %% [markdown]
# Concl.

# %% [markdown]
# ## 5. Bibliografía

# %% [markdown]
# 1\. Teorema de Bayes:
#
# 2\. Clasificador Bayesiano Sencillo:
#
# 3\. K-Nearest Neighbor:
#
# ID3 : Machine Learning, Tom Mitchell, Chapter 3 - http://www.cs.cmu.edu/~tom/mlbook.html
#
# 4\. Iris dataset: https://archive.ics.uci.edu/ml/datasets/iris
#
# 5\. Forest covertype dataset: https://archive.ics.uci.edu/ml/datasets/covertype
#
# 6\.
#
# 7\. Evaluación: material teórico del curso: https://eva.fing.edu.uy/pluginfile.php/240263/mod_resource/content/2/4-evaluacion.pdf
